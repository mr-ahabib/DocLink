# %% [raw]
# import os
# import glob as glob
# import matplotlib.pyplot as plt
# import cv2
# import requests
# import random
# import numpy as np
#
# np.random.seed(42)

# %%
TRAIN = True
EPOCHS = 200

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="EEMHk5pDwHCy58V7qoK2")
project = rf.workspace("university-of-engineering-and-management").project("doctor-prescription")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 33.9 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: certifi
# ...

# %%
import os 

if not os.path.exists('train'):


    dirs = ['/kaggle/working/doctor-prescription-6/train', '/kaggle/working/doctor-prescription-6/valid', '/kaggle/working/doctor-prescription-6/test']

    for dir_name in dirs:
        all_image_names = sorted(os.listdir(f"{dir_name}/images/"))
        for j, image_name in enumerate(all_image_names):
            if (j % 2) == 0:
                file_name = image_name.split('.jpg')[0]
                os.remove(f"{dir_name}/images/{image_name}")
                os.remove(f"{dir_name}/labels/{file_name}.txt")

# %%
def download_file(url, save_name):
    url = url
    if not os.path.exists(save_name):
        file = requests.get(url)
        open(save_name, 'wb').write(file.content)
    else:
        print('File already present, skipping download...')

# %%
import numpy as np

class_names_text = """A to Z
A-C
A-Calm
ATOZ Senior
ATV
AU-20
Abdolax
Abecab
Abetis Plus
Ace
Ace Plus
Acelex
Acifix
Aciphin
Acliz Plus
Acos
Actrapid
Adam 33
Airflow
Alarup
Alatrol
Alcet
Alex
Alfumax ER
Algecal D
Algecal DX
Algicid DX
Algin
Algita D
Almex
Alneed
Alphapress
Alve
Ambrox
Amdocal
Amikacin
Amilin
Amira
Amit
Amitriptyline
Anadol
Anaflex Max
Ancor
Androcap
Angenta
Anil
Anset
Antacid Plus
Antazol
Anustat
Anuva
Apitac
Aquafresh
Arbit
Arilin
Aristovit
Arsenor
Ascobex
Atin
Atova
Atrizin
Atropin
Augment
Avas
Avaspray
Avenac
Avlolac
Avolac
Axim CV
Axodin
Az
Azalid
Azicin
Azin
Azithrocin
Azithromycin
Azmasol HFA
Azolin
Azomac
Azyth
B Tonic
B-C
B126
Backtone
Bactin
Bactrocin
Becobion
Becoral D
Becoson
Becosules
Beklo
Benzapen
Betacap TR
Betanol
Betson
Bexitrol F
Bextram Gold
Bextram Silver
Bicozin
Bilan
Belfast
Biofol
Bislol
Bizoran
Block T
Bonova
Bopam
Bost
Boxol
Brezofil
Brodil Levo HFA
Brom
Budicort
Bukof
Byloza
Cafenol
Calamine
Calbo D
Calboral D
Calchek Plus
Calcifil-D
Calcin D
Caldi
Camlodin
Camlosart
Canvo
Cardinex
Cardinor
Careaid Man
Carmina
Caryon
Casalt D
Catson
Cavic-C Plus
Cebuten
Ceclav
Ceevit
Cef-3
Cef-3 DS
Cefaclav
Ceferon-3
Cefim-3
Cefixim
Ceflin
Cefotil
Cefotil Plus
Cefrox
Ceftax
Ceftid
Ceftizone
Ceftriaid
Ceftriaxone
Ceftron
Cefuclav
Cefuroxime
Cerox-CV
Cevit
Cfresh
Cholevit
Cildip
Cinaron
Cinaron Plus
Cinkara
Ciprocin
Clamox
Claricin
Clavurox
Roxadex
Roxilab
Roxyzin
Rozavel
Rupa
Rupanil
Rupin
Rutix
Rynex
Sagdon
Salazine
Salbutal
Salmolin
Scabo
Seasonix
Seclo
Secnid DS
Secular
Sentix
Sergel
Seroxyn
Silosin
Sinaflox
Sinafresh Liquigel
Sizonil
Solas
Solbion
Solivo
Solupred
Solvit B
Sonap
Sonexa
Spirocard Plus
Square Zinc
Starcef
Stressnil
Sugatrol
Sulbion
Sulprex
Sultolin
Supra B
Synogen Alfa
Syu
TPC
TT vax
Tamen
Tamen Turbo
Tamino
Taven
Tearon
Telazine
Telide
Telma
Telmacal
Tenil
Terbin
Tetrazin
Thyrin
Thyrox
Ticamet Inhaler
Ticas
Tiofoop Acecap
Tivis
Todol
Tofaxen
Tofen
Tofranil
Tolson
Tonamax
Topium Rotacap
Toradol
Torax
Torsid
Tory
Traxyl
Trego
Trexam
Tri-B
Tribion
Tridosil
Trilock
Triocim
Trizedon MR
Trugain
Trumega
Tryptin
Tufnil
Turboclav
UbiQ
Ulfate
Ulrif
Unifylin
Urikal
Uromax
Utifos
VT-3
Valestra
Valex
Vasco
Vave
Vaxtin
Vectra
Ventil Plus
Vergon
Vertina DX
Vertina Plus
Viodin
Virux
Visceralgine
Viscotin
Viset
Visonium
Visral
Vitabion
Volibo
Volinac
Voltalin
Voltalin SR
X-Cold
Xalcort
Xamic
Xeldrin
Xelpro
Xenole
Xenosal
Xetril
Xfin
Xinc B
Xorel
Xpa XR
Xpain
Xyclon
Xylocon
Xyril
Zeefol-CI
Zibac
Zif Forte
Zifolet
Zimax
Zinc
Ziton
Zo-Mups
Zoleta
Zovia Gold
Zox
Zymet
'remmo'"""

# Remove leading dashes and whitespace
class_names_text = class_names_text.replace('- ', '').replace('-','')

# Split the text into individual class names
class_names = class_names_text.split('\n')

# Generate random colors for each class
colors = np.random.uniform(0, 255, size=(len(class_names), 5))

# %%
# Function to convert bounding boxes in YOLO format to xmin, ymin, xmax, ymax.
def yolo2bbox(bboxes):
    xmin, ymin = bboxes[0]-bboxes[2]/2, bboxes[1]-bboxes[3]/2
    xmax, ymax = bboxes[0]+bboxes[2]/2, bboxes[1]+bboxes[3]/2
    return xmin, ymin, xmax, ymax

# %%
def plot_box(image, bboxes, labels,accuracy):
    # Need the image height and width to denormalize
    # the bounding box coordinates
    h, w, _ = image.shape
    for box_num, box in enumerate(bboxes):
        x1, y1, x2, y2 = yolo2bbox(box)
        # denormalize the coordinates
        xmin = int(x1*w)
        ymin = int(y1*h)
        xmax = int(x2*w)
        ymax = int(y2*h)
        width = xmax - xmin
        height = ymax - ymin

        class_name = class_names[int(labels[box_num])]

        cv2.rectangle(
            image,
            (xmin, ymin), (xmax, ymax),
            color=colors[class_names.index(class_name)],
            thickness=2
        )

        font_scale = min(1,max(3,int(w/500)))
        font_thickness = min(2, max(10,int(w/50)))

        p1, p2 = (int(xmin), int(ymin)), (int(xmax), int(ymax))
        # Text width and height
        tw, th = cv2.getTextSize(
            class_name,
            0, fontScale=font_scale, thickness=font_thickness
        )[0]
        p2 = p1[0] + tw, p1[1] + -th - 10
        cv2.rectangle(
            image,
            p1, p2,
            color=colors[class_names.index(class_name)],
            thickness=-1,
        )
        cv2.putText(
            image,
            class_name,
            (xmin+1, ymin-10),
            cv2.FONT_HERSHEY_SIMPLEX,
            font_scale,
            (255, 255, 255),
            font_thickness
        )
    return image

# %%
# Function to plot images with the bounding boxes.
def plot(image_paths, label_paths, num_samples):
    all_training_images = glob.glob(image_paths)
    all_training_labels = glob.glob(label_paths)
    all_training_images.sort()
    all_training_labels.sort()

    num_images = len(all_training_images)

    plt.figure(figsize=(15, 12))
    for i in range(num_samples):
        j = random.randint(0,num_images-1)
        image = cv2.imread(all_training_images[j])
        with open(all_training_labels[j], 'r') as f:
            bboxes = []
            labels = []
            label_lines = f.readlines()
            for label_line in label_lines:
                label = label_line[0]
                bbox_string = label_line[2:]
                x_c, y_c, w, h = bbox_string.split(' ')
                x_c = float(x_c)
                y_c = float(y_c)
                w = float(w)
                h = float(h)
                bboxes.append([x_c, y_c, w, h])
                labels.append(label)
        result_image = plot_box(image, bboxes, labels)
        plt.subplot(2, 2, i+1)
        plt.imshow(result_image[:, :, ::-1])
        plt.axis('off')
    plt.subplots_adjust(wspace=0)
    plt.tight_layout()
    plt.show()

# %%
 def set_res_dir():
    # Directory to store results
    res_dir_count = len(glob.glob('/kaggle/working/doctor-prescription-6/train/*'))
    print(f"Current number of result directories: {res_dir_count}")
    if TRAIN:
        RES_DIR = f"results_{res_dir_count+1}"
        print(RES_DIR)
    else:
        RES_DIR = f"results_{res_dir_count}"
    return RES_DIR

# %%
def monitor_tensorboard():
    # %load_ext tensorboard
    # %tensorboard --logdir runs/train

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16575, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 16575 (delta 28), reused 37 (delta 18), pack-reused 16522
# Receiving objects: 100% (16575/16575), 15.09 MiB | 31.33 MiB/s, done.
# Resolving deltas: 100% (11381/11381), done.

# %%
# %cd /kaggle/working/yolov5/
# Out:
# /kaggle/working/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 53.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.0/755.0 kB 39.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.5.0
#     Uninstalling Pillow-9.5.0:
#       Successfully uninstalled Pillow-9.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
monitor_tensorboard()
# Out:
#       <iframe id="tensorboard-frame-5f3b4f1040a00609" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-5f3b4f1040a00609");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !ls
# Out:
# CITATION.cff	 README.zh-CN.md  detect.py   pyproject.toml	tutorial.ipynb
# CONTRIBUTING.md  benchmarks.py	  export.py   requirements.txt	utils
# LICENSE		 classify	  hubconf.py  segment		val.py
# README.md	 data		  models      train.py

# %%
# %cd /kaggle/working/doctor-prescription-6
# Out:
# /kaggle/working/doctor-prescription-6

# %%
# !ls
# Out:
# README.dataset.txt  README.roboflow.txt  data.yaml  test  train  valid

# %%
# !python /kaggle/working/yolov5/train.py --img-size 640 --batch-size 16 --epochs 100 --data /kaggle/input/dataset/data.yaml --cfg /kaggle/working/yolov5/models/yolov5m.yaml --weights yolov5m.pt --name custom
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-04-30 16:47:38.853585: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 16:47:38.853643: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 16:47:38.854961: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...
